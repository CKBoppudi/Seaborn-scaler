# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # If we have one variable - Uni-variate analysis
# # If we have two variables - Bi-ltivariate analysis
# # If we have three variable - Multi-variate analysis

# %% [markdown]
# # There are two types of variables
# # 1. Categorical (C)
# # 2. Continous (Numerical(N))

# %% [markdown]
# # Combinations of variables for different analysis.
# # 1. Uni - variate analysis.
#
# #  Combination
#
# # N - Histogram (sns.histplot()) , kdeplot(sns.kdeplot()) , boxplot(sns.boxplot()) , barplot-single
#
# # C - countplot (sns.countplot) , barplot (sns.barplot())
#
# # 2. Bi - Variatae analysis
#
# # Combination
#
# # NN - scatterplot(sns.scatterplot()) , jointplot(sns.joinytplot()) , pairplot without hue , heatmap (sns.heatmap()) , lineplot (sns.lineplot())
#
# # CC - countplot with hue.
#
# # CN - Boxplot (sns.boxplot()) , violin plot (sns.violinplot()) , barplot (sns.barplot()) , piechart
#
#
# # 3. Multi - variate analysis
#
# #  Combination
#
# # NNN - scatter plot with size
#
# # CCC
#
# # NCC - barplot with hue , joint plot with hue , dodged , stacked
#
# # CNN - scatterplot with hue , jointplot(sns.jointplot()) with hue , pairplot with hue , lineplot(sns.lineplot()) , pairplot

# %% [markdown]
# # Inbuilt data sets in seaborn.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# # Loading a dataset

# %%
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.head(4)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %% [markdown]
# # Histograms depict frequencies (Used for single variable continous data).

# %%
sns.histplot(iris["sepal_length"])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris["petal_width"])
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# # KDE plot (Kernel density estimation plot).

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(iris["petal_width"])
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# # The above graph represents the probability distribution function (distribution of values).

# %%
sns.kdeplot(iris["petal_width"] , shade = True)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# # species is the categorical data

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # count plot

# %%
sns.countplot(data = iris , x = "species")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# # Understanding the relation between petal length and petal width.

# %%
 iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # petal_length and petal_width both are categorical data (NN)

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(data = iris , x = "petal_length" , y = "petal_width")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data = iris , x = "petal_length" , y = "petal_width" , hue = "species")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# # jointplot (without assigning "hue")

# %% [markdown]
# # We get histplot and scatterplot without using hue.

# %%
sns.jointplot(data = iris , x = "petal_length" , y = "petal_width")

# %%
sns.histplot(iris["petal_length"])
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(iris["petal_width"])
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# # Joint plot (Assigning "hue")

# %% [markdown]
# # we get kdeplot and Scatter plot when hue is assigned.

# %%
sns.jointplot(data = iris , x = "petal_length" , y = "petal_width" , hue = "species")

# %%
sns.kdeplot(iris["petal_length"] , shade = True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(iris["petal_width"] , shade = True)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# # Assigning "kind" to  jointplot

# %%
sns.jointplot(data = iris , x = "petal_length" , y = "petal_width" , hue = "species" , kind = "kde")

# %%
sns.jointplot(data = iris , x = "petal_length" , y = "petal_width" , kind = "reg")

# %%
sns.jointplot(data = iris , x = "petal_length" , y = "petal_width" , kind = "hist")

# %%
sns.jointplot(data = iris , x = "petal_length" , y = "petal_width" , hue = "species" , kind = "hist")

# %% [markdown]
# # pairplot

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data = iris , hue = "species")

# %% [markdown]
# # Pairplot withou hue

# %%
sns.pairplot(data = iris)

# %%
sns.pairplot(data = iris , kind = "reg")

# %% [markdown]
# # The above gives the correlation between x and y

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# # sepal_width and species (numerical-categorical(CN))

# %%
sns.boxplot(data = iris , x = "species" , y = "sepal_width")
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# # Calculating Inter quartile ranges.

# %% [markdown]
# # Inter Quartile Range (IQR) for setosa = q3 - q1 = 3.8 - 3.3 = 0.5

# %% [markdown]
# # Inter Quartile Range (IQR) for versicolor = q3 - q1 = 3 - 2.5 = 0.5

# %% [markdown]
# # Inter Quartile Range (IQR) for virginica = q3 - q1 = 3.2 - 2.7 = 0.5

# %% [markdown]
# # ############--------- Use cases of boxplot ----------#######
# # 1. Stock markets.
# # 2. To detect range.
# # 3. To detect outliers.
# # 4. To identify IQR (Inter quartile range) --IQR is the range between 25th percentile and 75th percentile

# %% [markdown]
# # ##########---------- Outlier Formula ----------##########

# %% [markdown]
# # Outlier lower bound ---- Q1 - (IQR * 1.5)
# # points below the lower bound are lower outliers
# # Q1 = 1st Quartile
# # IQR = Q3 - Q1

# %% [markdown]
# # Outlier upper bound ---- Q3 +( IQR * 1.5)
# # points above the upper bound are upper outliers
# # Q3 = 3rd Quartile
# # IQR = Q3 - Q1

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(data = iris , x = "species" , y = "sepal_width")
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# # Violin plot give the kde plot and box plot as seen above.

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(data = titanic , x = "sex" , y = "age" , hue = "alive" )
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# # Correlation

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# # heatmap

# %%
sns.heatmap(iris.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr() , annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr() , annot = True , cmap = "Blues")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr() , annot = True , vmin = -1 , vmax = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # color maps (All the colors that are available)

# %%
plt.colormaps()
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  'afmhot',
#  'afmhot_r',
# ...

# %% [markdown]
# # Line plot

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.lineplot(data = iris , x = "sepal_length" , y = "sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # The shade is the confidence interval in the above.

# %% [markdown]
# # Seperating the line plot with respect to hue = "species"

# %%
sns.lineplot(data = iris , x = "petal_length" , y = "sepal_width" , hue = "species")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>

# %% [markdown]
# # Working on a different data set.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # How many males and females are there in the data set ?
# # What plot should be used ?

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.countplot(data = tips , x = "sex")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
tips["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# # caclulate how many males are smokers and how many females are smokers
# # Which plot is used.

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.countplot(data = tips , x = "sex" , hue = "smoker")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
tips[["sex" , "smoker"]].value_counts()
# Out:
# sex     smoker
# Male    No        97
#         Yes       60
# Female  No        54
#         Yes       33
# dtype: int64

# %% [markdown]
# # Find out all the smokers and non-smokers.

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.countplot(data = tips , x = "smoker" , hue = "sex")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data = tips , x = "smoker" , hue = "sex" , dodge = False)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(data = titanic , x = "survived" , y = "age" , hue = "alone")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# # Bar plots

# %%
sns.barplot(data = tips , x = "day" , y = "total_bill")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data = tips , x = "day" , y = "total_bill" , hue = "sex" , estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data = tips , x = "day" , y = "total_bill" , hue = "smoker" , estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(data = tips , x = "tip" , y = "total_bill" , size = "size")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(data = tips , x = "tip" , y = "total_bill" , size = "size" , hue= "sex")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>
